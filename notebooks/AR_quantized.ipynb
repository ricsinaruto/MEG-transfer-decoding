# %%
import os
import numpy as np
import mne
import osl
import scipy
import yaml
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler, RobustScaler, StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import MiniBatchKMeans
import seaborn as sns
import numpy as np
import pickle
import matplotlib.pyplot as plt

# %%
path = os.path.join('..', 'results', 'cichy_epoched', 'subj1', 'cont_quantized', 'AR_multi', 'outputs.npy')
preds = np.load(path)[:, :, 0]

path = os.path.join('..', 'results', 'cichy_epoched', 'subj1', 'cont_quantized', 'AR_multi', 'target.npy')
targets = np.load(path)[:, :, 0]

# %%
# %matplotlib widget
plt.plot(preds[0, 1000:1100], linewidth=0.5)
plt.plot(targets[0, 1000:1100], linewidth=0.5)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean((targets.reshape(-1) - preds.reshape(-1))**2)
# Out:
# 6583072448113131.0
