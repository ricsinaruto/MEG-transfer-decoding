# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import mne
import pickle
import seaborn as sns
import pandas as pd
from scipy import stats
#from statannotations.Annotator import Annotator

# %%
path = os.path.join('..', 'results', 'things_epoched', 'test_lda_25hz_conv80', 'subj1',
                    'val_loss_PFIts.npy')
pfits = np.load(open(path, 'rb'))
pfits = pfits[0, 0] - pfits

# %%
pfits_pd.shape
# Out:
# (410,)

# %%
times = np.array([np.arange(50, 460, 10) for _ in range(pfits.shape[0])])
pfits_pd = pfits.reshape(-1)
times = times.reshape(-1)
pfits_pd = pd.DataFrame({'Accuracy loss': pfits_pd, 'Time (ms)': times})

# %%
# %matplotlib widget
pfi_plot = sns.relplot(
    data=pfits_pd, kind="line",
    x="Time (ms)", y="Accuracy loss", n_boot=10, legend=None, aspect=1.1
)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
